# %%
import sys, os
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\temp\ipykernel_13328\1229095084.py in <module>
#       1 import sys, os
#       2 import os
# ----> 3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\temp\ipykernel_13328\352233182.py in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#
# C:\anaconda\envs\AoC\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2362                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363             with self.builtin_trap:
# -> 2364                 result = fn(*args, **kwargs)
#    2365             return result
#    2366
#
# C:\anaconda\envs\AoC\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# C:\anaconda\envs\AoC\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\anaconda\envs\AoC\lib\site-packages\IPython\core\magics\pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# C:\anaconda\envs\AoC\lib\site-packages\IPython\core\interactiveshell.py in enable_matplotlib(self, gui)
#    3531         """
#    3532         from IPython.core import pylabtools as pt
# -> 3533         from matplotlib_inline.backend_inline import configure_inline_support
#    3534         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    3535
#
# C:\anaconda\envs\AoC\lib\site-packages\matplotlib_inline\__init__.py in <module>
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"  # noqa
#
# C:\anaconda\envs\AoC\lib\site-packages\matplotlib_inline\backend_inline.py in <module>
#       4 # Distributed under the terms of the BSD 3-Clause License.
#       5
# ----> 6 import matplotlib
#       7 from matplotlib import colors
#       8 from matplotlib.backends import backend_agg
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
#!pip install advent-of-code-data
#https://github.com/wimglenn/advent-of-code-data #for input parsing/loading
from aocd import get_data # simple, #get_data(day=24, year=2021)
from aocd.models import Puzzle

# %%
# run ONCE 
puzzle = Puzzle(year=2021, day=16)
print(puzzle.user)
print(puzzle.input_data_fname)
print(puzzle.example_input_data_fname)

iA = puzzle.input_data
iE = puzzle.example_data
# Out:
# <User github.Ryton.1321098 (token=...9e51)>
# C:\Users\joachim.verhelst\.config\aocd\github.Ryton.1321098\2021_16_input.txt
# C:\Users\joachim.verhelst\.config\aocd\github.Ryton.1321098\2021_16_example_input.txt

# %%
# test and solve part A
#iA,iE, 

class a:
    def __init__(self,i = None):
        self.input = i
        pass
    def fun(self,params=None):
        print('hello')
        pass
    
    
def fun2():
    print('world')
    pass

# %%
# i = iE
# a_obj = a(i)
# a_obj.fun()

answA = fun2()
print(answA)
# Out:
# hello
# world

# %%
dummy_float_a = 123.0
puzzle.answer_a = dummy_float_a # this submits!
# Out:
# wrong answer: 123.0
# That's not the right answer.  If you're stuck, make sure you're using the full input data; there are also some general tips on the about page, or you can ask for hints on the subreddit.  Please wait one minute before trying again. (You guessed 123.0.) [Return to Day 16]

# %%
dummy_int_a = int(123)
puzzle.answer_a = dummy_int_a # this submits!
# Out:
# wrong answer: 123
# That's not the right answer; your answer is too low.  If you're stuck, make sure you're using the full input data; there are also some general tips on the about page, or you can ask for hints on the subreddit.  Please wait one minute before trying again. (You guessed 123.) [Return to Day 16]

# %%
answB= funB()
print(answB)

# %%
puzzle.answer_b =  # this submits!
# Out:
#   Cell In [40], line 1
#     puzzle.answer_b =  # this submits!
#                        ^
# SyntaxError: invalid syntax

# %%
def test_yield(init = 5):
    memory = init   
    add = 2
    while True:
        memory += add
        message = yield memory + add
        if message != None:
            add = message[0]
        else:
            add = 0

f_using_yield = test_yield(2.5)
f_using_yield.send(None)
print(next(f_using_yield))
f_using_yield.send([1, 0, 0])
print(next(f_using_yield))
f_using_yield.send([2, 0, 0])
print(next(f_using_yield))
f_using_yield.send([3, 0, 0])
print(next(f_using_yield))
# Out:
# 4.5
# 5.5
# 7.5
# 10.5

# %%
 def letter_generator(text):
     position = 0
     while True:
         message = yield text[position]
         if message!= None:
             position = message
         else:
             position += 1
 
letters = letter_generator("abcdefghijklmnopqrstucwxyz")

# %%
next(letters)
# Out:
# 'a'

# %%
letters.send(5)
# Out:
# 'f'

# %%
puzzle.get
