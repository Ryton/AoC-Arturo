# %%
import sys, os
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# %matplotlib inline

# %%
# %load_ext pycodestyle_magic
# %pycodestyle_on 
# %pycodestyle_off
# Out:
# The pycodestyle_magic extension is already loaded. To reload it, use:
#   %reload_ext pycodestyle_magic

# %%
#!pip install advent-of-code-data
#https://github.com/wimglenn/advent-of-code-data #for input parsing/loading
from aocd import get_data # simple, #get_data(day=24, year=2021)
from aocd.models import Puzzle
# Out:
# 1:1: E265 block comment should start with '# '
# 2:1: E265 block comment should start with '# '
# 3:26: E261 at least two spaces before inline comment

# %%
# run ONCE 
puzzle = Puzzle(year=2022, day=5)
print(puzzle.user)
print(puzzle.input_data_fname)
print(puzzle.example_input_data_fname)

iA = puzzle.input_data
iE = puzzle.example_data
print(iE)
# Out:
# <User github.Ryton.1321098 (token=...9e51)>
# C:\Users\joachim.verhelst\.config\aocd\github.Ryton.1321098\2022_05_input.txt
# C:\Users\joachim.verhelst\.config\aocd\github.Ryton.1321098\2022_05_example_input.txt
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2

# %%
# test and solve part A
#iA,iE, 
def parse_pile(i=None):
    p=i.split('/n/n')
    piles_str=p[0]
    piles_str_lines = piles_str.split('\n')
    npiles = int( round(len(piles_str_lines[0] )+1)/4)
    #print(npiles)
    #piles = dict(zip(range(int(npiles)),[]*npiles))
    #piles=dict(zip([0,1,2],[[],[],[]]))
    piles=dict(zip(range(npiles),[[] for j in range(npiles)]))
    
    #print(piles)
    oneline_list = []
    for line_str in piles_str_lines:
        if ' 1   2   3 ' in line_str:
            for i in piles.keys():
                piles[i].reverse()
            return piles
        for i in piles.keys():
            if line_str[1+4*i] != ' ':
                piles[i].append(line_str[1+4*i] )

             
def parse_task(i=None):
    p=i.split('\n\n')
    tasks=p[1]
    #" move 1 from 1 to 2
    tuple_of_tasks = []
    #print(tasks)
    task_list=tasks.split('\n')
    for line in task_list:
        list_line=line.split(' ')
        #print(list_line)
        howmuch_=int(list_line[1])
        from_=int(list_line[3])
        to_ = int(list_line[5])
        tuple_of_tasks.append( (howmuch_,from_,to_))
    return tuple_of_tasks
          
class a:
    def __init__(self,i = None):
        self.input = i
        pass
    def fun(self,params=None):
        print('hello')
        pass
    
    
def exec_one_task_one_at_a_time(piles=None,task_tuple=(0,0,0)):
    task_tuple #(howmuch_,from_,to_))
    howmuch_= task_tuple[0]
    from_= task_tuple[1]-1
    to_= task_tuple[2]-1
    
    for j in range(task_tuple[0]):
        piles[to_].append(piles[from_].pop())
    return piles

def exec_one_task_all_together(piles=None,task_tuple=(0,0,0)):
    task_tuple #(howmuch_,from_,to_))
    howmuch_= task_tuple[0]
    from_= task_tuple[1]-1
    to_= task_tuple[2]-1
    
    piles[to_].extend(piles[from_][-howmuch_:])
    for n in range(howmuch_):
        piles[from_].pop()
    return piles
    
        
    return piles

tasks =parse_task(iE)
piles = parse_pile(iE)
print(piles) #already reversed.!
#test = exec_one_task(piles,(1,2,1))


for task in tasks:
    #print(piles)
    #print(task)
    piles = exec_one_task_one_at_a_time(piles,task)
    
answA=''


for keyval in piles.keys():
    answA +=piles[keyval][-1]
    
print(answA)


#taskB
tasks =parse_task(iA)
piles = parse_pile(iA)

for task in tasks:
    #print(piles)
    #print(task)
    piles = exec_one_task_all_together(piles,task)
    
answB=''
for keyval in piles.keys():
    answB +=(piles[keyval][-1])
    
print(answB)
# Out:
# {0: ['Z', 'N'], 1: ['M', 'C', 'D'], 2: ['P']}
# CMZ
# GGNPJBTTR

# %%
# i = iE
# a_obj = a(i)
# a_obj.fun()

answA = 'QNNTGTPFN'
print(answA)
# Out:
# QNNTGTPFN

# %%
for j in range(5,0,-1):
    print(j)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
puzzle.answer_a = answA # this submits!
# Out:
# That's the right answer!  You are one gold star closer to collecting enough star fruit. [Continue to Part Two]

# %%
# test and solve part B, use inputs & test inputs.

# %%
answB='GGNPJBTTR'
print(answB)
# Out:
# GGNPJBTTR

# %%
puzzle.answer_b = answB # this submits!
# Out:
# That's the right answer!  You are one gold star closer to collecting enough star fruit.You have completed Day 5! You can [Shareon
#   Twitter
# Mastodon] this victory or [Return to Your Advent Calendar].

# %%
def test_yield(init = 5):
    memory = init   
    add = 2
    while True:
        memory += add
        message = yield memory + add
        if message != None:
            add = message[0]
        else:
            add = 0

f_using_yield = test_yield(2.5)
f_using_yield.send(None)
print(next(f_using_yield))
f_using_yield.send([1, 0, 0])
print(next(f_using_yield))
f_using_yield.send([2, 0, 0])
print(next(f_using_yield))
f_using_yield.send([3, 0, 0])
print(next(f_using_yield))
# Out:
# 4.5
# 5.5
# 7.5
# 10.5

# %%
 def letter_generator(text):
     position = 0
     while True:
         message = yield text[position]
         if message!= None:
             position = message
         else:
             position += 1
 
letters = letter_generator("abcdefghijklmnopqrstucwxyz")

# %%
next(letters)
# Out:
# 'a'

# %%
letters.send(5)
# Out:
# 'f'
