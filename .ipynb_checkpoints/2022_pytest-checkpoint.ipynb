# %%
#!pip install advent-of-code-data
#https://github.com/wimglenn/advent-of-code-data #for input parsing/loading

# %%
import sys, os
import os

# %%
from aocd import get_data # simple
from aocd.models import Puzzle

# %%
#get_data(day=24, year=2021)

# %%
# run ONCE 
puzzle = Puzzle(year=2021, day=1)
print(puzzle.user)
print(puzzle.input_data_fname)
print(puzzle.example_input_data_fname)

iA = puzzle.input_data
iE = puzzle.example_data
# Out:
# <User github.Ryton.1321098 (token=...9e51)>
# C:\Users\joachim.verhelst\.config\aocd\github.Ryton.1321098\2021_01_input.txt
# C:\Users\joachim.verhelst\.config\aocd\github.Ryton.1321098\2021_01_example_input.txt

# %%
print(iE)
# Out:
# 199
# 200
# 208
# 210
# 200
# 207
# 240
# 269
# 260
# 263

# %%
puzzle.answer_a('3262991')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 puzzle.answer_a('3262991')
#
# TypeError: 'str' object is not callable
