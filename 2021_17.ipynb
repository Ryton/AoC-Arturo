# %%
import sys, os
import os
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# %matplotlib inline

# %%
# %load_ext pycodestyle_magic
# %pycodestyle_on 
# %pycodestyle_off

# %%
# !pip install advent-of-code-data
# https://github.com/wimglenn/advent-of-code-data #for input parsing/loading
from aocd import get_data  # simple, #get_data(day=24, year=2021)
from aocd.models import Puzzle

# %%
#  run ONCE
puzzle = Puzzle(year=2021, day=17)
#print(puzzle.user)
print(puzzle.input_data_fname[60:])
print(puzzle.example_input_data_fname[60:])

iA = puzzle.input_data
iE = puzzle.example_data
print(iE)
# Out:
# 2021_17_input.txt
# 2021_17_example_input.txt
# target area: x=20..30, y=-10..-5

# %%
print(iA)
# Out:
# target area: x=139..187, y=-148..-89

# %%
# test and solve part A
# iA,iE,

xe = np.linspace(20.,30.,11)
ye = np.linspace(-10.,-5.,6) #example

xa = np.linspace(139,187,187-139+1)
ya = np.linspace(-148,-89,148-89+1) #a

niter = 100


def oneDcase(ty , tx, niter = 100):
    #vx_eval = np.linspace(0,200.,21)  #7
    ## FULL MONTHY
    vy_eval = np.linspace(0.,99999999,99999999+1) #2
    ## normal MONTHY
    #vy_eval = np.linspace(0.,99999999,99999999+1) #2
    heights,vector,vxy=[],[],[]

    for vyi in vy_eval:
        if 1: #for vxi in vx_eval:
            #initial vals
            #x=  0 
            y = 0
            #vx = vxi
            vy = vyi

            y_=[]
            path_=[]
            
            for i in range(niter):
                #print(i)
                # apply drag and gravity  
                vy += -1  # velocity drops by one every
                #vx += -1*np.sign(vx)

                # location update
                y +=  vy
                #x +=  vx
                y_.append(y) # historic heights.
                path_.append((y,y))
                
                if y in ty:
                    if 0: #if x in tx:
                        pass
                    heights.append(max(y_))
                    vector.append((y,y))
                    vxy.append((vyi,vyi))
                        #print(vector)

    return heights,vector,vxy

#example
heights,vector,vxy=  oneDcase(ya,xa)

print('max_height')
print(max(heights))
if 0:
    print()
    print('landing_point')
    print(vector)
    print()
    print('vel vector')
    print(vxy)

# %%
# i = iE
# a_obj = a(i)
# a_obj.fun()

target_range_y=ye
print(ye)
# Out:
# [-10.  -9.  -8.  -7.  -6.  -5.]

# %%
np.linspace(-10.,-5.,6)
# Out:
# array([-10.,  -9.,  -8.,  -7.,  -6.,  -5.])

# %%
answA=1176.0
puzzle.answer_a = answA # this submits!
# Out:
# coercing float value
# wrong answer: 1176
# That's not the right answer.  If you're stuck, make sure you're using the full input data; there are also some general tips on the about page, or you can ask for hints on the subreddit.  Because you have guessed incorrectly 6 times on this puzzle, please wait 5 minutes before trying again. (You guessed 1176.) [Return to Day 17]

# %%
# test and solve part B, use inputs & test inputs.

# %%
answB= funB(i=iE)
print(answB)

# %%
puzzle.answer_b = answB # this submits!
