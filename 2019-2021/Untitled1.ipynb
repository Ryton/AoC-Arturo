# %%
import math
dict_= {-1:"/ ",0:" ",1:"|"}
rev = dict(zip(dict_.values(),dict_.keys()))
def printtree(n=0):
    print('printtree({})'.format(n))
    print('----------')
    lower_rung_left = ""

    a =n
    lower_rung_right = ""
    while (a >=2):
        lower_rung_left +=dict_[-1]+dict_[0]+dict_[1]
        a -=2
    if (a ==1):
        lower_rung_left += dict_[0] + dict_[1]
    print('len',len(lower_rung_left))
    #print(upper_rung(lower_rung_left)+lower_rung_left)
    print(lower_rung_left)
    
def upper_rung(charlist):
    width = len(charlist)
    the_end = True
    out_str = ""
    next_line =list(' ' * width)
    
    for i in range(0,width):
        val=charlist[i:i+2]
        if val in rev:
            #print(i, ':',i-1*rev[val])
            next_line[i-1*rev[val]]= val #-1*rev[val]
        if val is not dict_[0]:
            the_end=False
    if the_end:
        
        return out_str.join(next_line)+'\n'
    else:
        return upper_rung(next_line) + out_str.join(next_line) + "\n"

# %%
printtree(5)
# Out:
# printtree(5)
# ----------
# len 10
# /  |/  | |

# %%
dict_= {-1:"/ ",0:" ",1:" \\"}
a=dict_.values()
print(dict(zip(dict_.values(),dict_.keys())))
# Out:
# {'/ ': -1, ' ': 0, ' \\': 1}

# %%
next_line =' ' * 5
len(next_line)
# Out:
# 5
