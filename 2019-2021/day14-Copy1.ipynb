# %%
import AoC_helper
import os, sys
import numpy as np
import math
#import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import copy
import csv #for load from file
import pandas as pd
import time
 
# we initialize the variable start
# to store the starting time of
# execution of program

# %%
#helper =  AoC_helper.text_functions()
#import input_scrub
#parser = input_scrub.parse_from_URL(day=12,filename='input12.txt')

# %%
#df =helper.load_to_pandas(filename='input12.txt', delimeter=",")
df= pd.read_csv('input14.txt',header=None)
big_valuelist = df.values[1:] #full
big_polymer= df.values[0][0] #full

small_polymer= 'NNCB' #full

small_puzzleinput=[['CH -> B'],['HH -> N'],['CB -> H'],['NH -> C'],['HB -> C'],['HC -> B'],['HN -> C'],['NN -> C'],['BH -> H'],['NC -> B'],['NB -> B'],['BN -> B'],['BB -> N'],['BC -> B'],['CC -> N'],['CN -> C']]

puzzle_input = small_puzzleinput
polymer=small_polymer
print(polymer,puzzle_input)
# Out:
# NNCB [['CH -> B'], ['HH -> N'], ['CB -> H'], ['NH -> C'], ['HB -> C'], ['HC -> B'], ['HN -> C'], ['NN -> C'], ['BH -> H'], ['NC -> B'], ['NB -> B'], ['BN -> B'], ['BB -> N'], ['BC -> B'], ['CC -> N'], ['CN -> C']]

# %%
# Out:
# ['CH', 'HH', 'CB', 'NH', 'HB', 'HC', 'HN', 'NN', 'BH', 'NC', 'NB', 'BN', 'BB', 'BC', 'CC', 'CN']
# ['B', 'N', 'H', 'C', 'C', 'B', 'C', 'C', 'H', 'B', 'B', 'B', 'N', 'B', 'N', 'C']

# %%
def build_templates(puzzle_input):
    pairs_template =[]
    inject_template= []
    for conn in puzzle_input:
        #print(conn)
        items =conn[0].split(" ")
        pairs_template.append(items[0])
        inject_template.append(items[2])
    #print(pairs_template)
    #print(inject_template)
    return pairs_template,inject_template

def one_cycle(polymer,pairs_template,inject_template):
    inject_letter=[]
    inject_pos=[]
    for n in range(len(pairs_template)):
        curr_pair = pairs_template[n]
        pos =-9999
        while not (pos ==-1):
            pos =polymer.find(curr_pair,pos+1)
            #print(curr_pair,pos)
            if pos > 0: 
                #print('found ',curr_pair,' at pos ', pos)
                inject_letter.append(inject_template[n])
                inject_pos.append(pos+1)
            elif pos==0 and curr_pair == polymer[0:2]:

                #print('found ',curr_pair,' at pos ', pos)
                inject_letter.append(inject_template[n])
                inject_pos.append(pos+1)

    #print(inject_letter,inject_pos)
    
    return inject_letter,inject_pos


def crisper(text,place,char):
    return text[:place] + char + text[place:]

def inject(polymer, inject_letter,inject_pos):
    tupled = list(zip(inject_pos,inject_letter))
    #print(tupled)
    tupled.sort(reverse=True)
    
    for injection in tupled:
        
        polymer = crisper(polymer,injection[0],injection[1])
    return polymer
             
    

#answer_from_site ='NBCCNBBBCBHCB'
                #"  NBCCNBBBCBHCB"
    
    #from site#NBBBCNCCNBNBBCHBHHBCB
              #NBBBCNCCNBNBBCHBHHBCB
  #from site 'NBBNBNBBCCNBCNCCNBBNBBNBBBNBBNBBCBHCBHHNHCBBCBHCB'
             #NBBNBBNBBBBCNCCNBCNBCNBBNBBCHBHHBCBHNHCNCHCBCBHB

# %%
#df =helper.load_to_pandas(filename='input12.txt', delimeter=","
#puzzle_input = small_puzzleinput
#polymer=small_polymer
puzzle_input = big_valuelist
polymer=big_polymer

#print(polymer,puzzle_input)


pairs_template,inject_template =build_templates(puzzle_input)
new_polymer=polymer
for i in range(10+1):
    polymer = new_polymer
    inject_letter,inject_pos= one_cycle(polymer,pairs_template,inject_template)
    new_polymer=inject(polymer, inject_letter,inject_pos)
print('after step ',i+1,':',len(polymer), polymer)
# Out:
# after step  11 : 19457 ...

# %%
letterset = set(polymer)
print(letterset)
counts=[]
for i in letterset:
    print(i,polymer.count(i)) #58 = wrong.
    counts.append(polymer.count(i))
    
print('13a',max(counts)-min(counts)) #correct
# Out:
# {'S', 'V', 'C', 'N', 'B', 'O', 'F', 'P', 'K', 'H'}
# S 2027
# V 2184
# C 2102
# N 1226
# B 1474
# O 3053
# F 1321
# P 3553
# K 654
# H 1863
# 13a 2899

# %%
pairs_template,inject_template =build_templates(puzzle_input)
new_polymer=polymer
for i in range(40+1):
    polymer = new_polymer
    inject_letter,inject_pos= one_cycle(polymer,pairs_template,inject_template)
    new_polymer=inject(polymer, inject_letter,inject_pos)
letterset = set(polymer)
print(letterset)
counts=[]
for i in letterset:
    print(i,polymer.count(i)) #58 = wrong.
    counts.append(polymer.count(i))
    
print('13b',max(counts)-min(counts)) #150895 in 39 steps = too low. 226255 too low;
# Out:
# {'S', 'V', 'C', 'N', 'B', 'O', 'F', 'P', 'K', 'H'}
# S 164413
# V 173760
# C 182823
# N 67348
# B 164083
# O 203072
# F 111824
# P 355375
# K 53760
# H 132522
# 13b 301615

# %%
if not naive:
    start = time.time()
    print("day 12 a less naive")
    nextpath=[['start']]

    for iteration in range(10):
        paths = nextpath.copy()
        print('iteration: ',iteration)
        path_number=-1
        for ways in paths:
            for trial in connections:
                if len(ways)>=iteration:
                #print(trial)
                    path_number +=1 #path index
                    extended_ways = check_and_return(ways,trial)
                    #print(extended_ways)
                    if extended_ways is None:
                        pass
                    else:
                        nextpath.append(extended_ways)
        #print(nextpath)
    end = time.time()

    counter=0
    paths = nextpath.copy()
    for way in paths:
        if "end" in way:
            counter+=1
    print('day12a: ',counter)
    print
