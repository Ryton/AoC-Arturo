# %%
import AoC_helper
import os, sys
import numpy as np
import math
#import pandas as pd
import numpy.matlib
import matplotlib.pyplot as plt
import copy
import csv #for load from file
import pandas as pd

# %%
helper =  AoC_helper.text_functions()
df =helper.load_to_pandas(filename='input6.txt', delimeter="")



valuelist = [3,4,3,1,2] # demo
valuelist = df.values[0] #full

fishtypes_days = np.zeros([9,257])
for el in valuelist:
    fishtypes_days[el,0] +=1

print(fishtypes_days[:,0])
# Out:
# [  0. 180.  36.  30.  26.  28.   0.   0.   0.]

# %%
def age(fishtypes_days,curr_day):
    currgen=fishtypes_days[:,curr_day]
    nextgen=np.zeros([9])
    nextgen[6] += currgen[0]
    nextgen[8] += currgen[0]
    for agegroup in range(len(currgen)):

        if (agegroup == 0):
            pass
        else:
            nextgen[agegroup-1] += currgen[agegroup]
    #print(nextgen)
    return nextgen
print(age(fishtypes_days,0))
# Out:
# [180.  36.  30.  26.  28.   0.   0.   0.   0.]

# %%
for day in range(256):
    #print(nextgen)
    fishtypes_days[:,day+1]=age(fishtypes_days,day)

print(fishtypes_days[:,256])
print(sum(fishtypes_days[:,256]))
# Out:
# [1.45343738e+11 1.77707731e+11 1.83720927e+11 1.98364418e+11
#  2.32411820e+11 2.24133631e+11 2.84527486e+11 1.19748508e+11
#  1.55190553e+11]
# 1721148811504.0
